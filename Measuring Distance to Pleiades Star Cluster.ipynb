# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate
from scipy.optimize import curve_fit
# %matplotlib inline
plt.rcParams.update({'font.size': 22})
plt.rcParams["figure.figsize"] = (15,10)

# %%
#BV=np.array([0.81,-0.11,0.35,0.55,1.02,1.01,0.36,0.99,0.64,0.02,.47,1.18,-.09,1.23,.68,1.15,1.7,-0.7,.56,0.12,.78,1.17,.17,.13])
#Vapparent=np.array([12.51,4.31,8.6,9.7,12.05,14.36,8.11,12.02,10.52,6.8,9.46,12.61,2.87,7.72,16.36,8.8,6.46,5.45,10.02,6.95,11.35,15.69,9.17,7.42])
BV=np.array([0.62])
Vapparent=np.array([4.7])

# %%
Vabs=np.array([-5.8,-4.1,-1.1,-.7,2,2.6,3.4,4.4,5.1,5.9,7.3,9,11.8,16])
BVab=np.array([-.35,-.31,-.16,0,.13,.27,.42,.58,.7,.89,1.18,1.45,1.63,1.80])

# %%
plt.plot(BVab,Vabs+.1)
plt.scatter(BV,Vapparent,c='black')
ax = plt.gca()
ax.invert_yaxis()
plt.title("Photoelectric Photometry of the Peiades Star Cluster")
plt.xlabel('B-V')
plt.ylabel('Absolute Magnitude (M)')
plt.legend(['Model Main Sequence','Data Collected'])
plt.grid(True)

# %%
BV1=np.array([0.81,-0.11,0.35,0.55,1.02,1.01,0.36,0.99,0.64,0.02,.47,1.18,-.09,1.23,.68,1.15,1.7,-0.7,.56,0.12,.78,1.17,.17,.13])
Vapparent1=np.array([12.51,4.31,8.6,9.7,12.05,14.36,8.11,12.02,10.52,6.8,9.46,12.61,2.87,7.72,16.36,8.8,6.46,5.45,10.02,6.95,11.35,15.69,9.17,7.42])
Vabs1=np.array([-5.8,-4.1,-1.1,-.7,2,2.6,3.4,4.4,5.1,5.9,7.3,9,11.8,16])
BVab1=np.array([-.35,-.31,-.16,0,.13,.27,.42,.58,.7,.89,1.18,1.45,1.63,1.80])

# %%
plt.scatter(BV1,Vapparent1,label="Data Collected",marker='o',c="black",)
plt.plot(BVab1,Vabs1+5.5,label='Model Main Sequence')
plt.plot(BVab1,Vabs1+5.8,c="red",label='Error Boundary')
plt.plot(BVab1,Vabs1+5.3,c='red')

#Take error to be arouund +-.3  from 5.5
ax = plt.gca()
ax.invert_yaxis()
plt.title("Photoelectric Photometry of the Peiades Star Cluster")
plt.xlabel('B-V')
plt.ylabel('Absolute Magnitude (M)')
plt.legend()
plt.grid(True)
